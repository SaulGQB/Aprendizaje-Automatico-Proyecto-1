# %% [markdown]
# # 3. Análisis de libreria (B) y Sklearn

# %% [markdown]
# ## Carga de librerias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# ## Análisis de las bases de datos

# %% [markdown]
# Los archivos con las datos correspondientes se cargan a través de la librería pandas con ``pandas.read_csv()``, en este caso se específica el delimitador como "**;**".
# El dataframe creado con nombre df_red corresponde a los datos existentes para la calidad de vino tinto, mientras que df_white corresponde a los datos para la calidad del vino blanco.

# %%
df_red = pd.read_csv('datos/winequality-red.csv', delimiter=';')
df_white = pd.read_csv('datos/winequality-white.csv', delimiter=';')

# %% [markdown]
# ### Aplicación del método ``df.describe()``

# %% [markdown]
# Con el método ``df.describe`` se describen los datos estadisticamente, con esta es posible apreciar la cantidad de datos disponibles por columna, además de información significativa como la media, los valores mínimos y los máximos.
# Como puede observarse, en cada dataframe (df_red y df_white) existen tres columnas que podrían no normalizarse de 0 a 1, pues ya poseen este rango.

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# ### Aplicación del método  ``df.info()``

# %% [markdown]
# Con el método ``df.info()`` observamos las diferentes columnas que poseen los dataframes, la existencia de valores nulos, la cantidad de datos y el tipo de dato por columna.
# Como puede observarse no se cuenta con valores ``null`` o ``NaN`` en ambos dataframes, el dataframe **df_red** cuenta con 1599 datos por columna, siendo todas de tipo float64, por su parte, el dataframe **df_white** cuenta con 4898 datos por columna de tipo float64. Ambos dataframe poseen las mismas columnas y en ambos casos la columna "_quality_" es de tipo entero.

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# No hay valores ``null`` o ``NaN``.

# %% [markdown]
# ### Mostrando las distribuciones para cada columna de datos

# %% [markdown]
# Para describir los datos gráficamente se utilizan las graficas de distribución a través de una función llamada ``plot_dis()``, en esta se utiliza el control de errores ``try - except`` para así utilizar la función obsoleta ``seaborns.distplot()``, en este caso utilizar la función de distribución actual disponible de la libreria **seaborns** ``seaborns.displot()`` genera un bug que provoca que no se reconozcan los ``subplot()``, por ello en caso de que la función primera sea removida se tiene como excepción el uso de ``hist()`` propio de **matplotlib**.

# %% [markdown]
# #### Para el vino tinto

# %%
def plot_dis(df):
    plt.figure(figsize=(20,15))
    col = df.columns
    for i in range(len(df.columns)):
        try:
            plt.subplot(4, 3, i + 1)
            sns.distplot(df[col[i]])
        except:
            plt.subplot(4, 3, i + 1)
            plt.hist(df[col[i]], 6)
    
plot_dis(df_red)
# Out:
# /home/saul_gqb/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/saul_gqb/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# #### Para el vino blanco

# %%
plot_dis(df_white)
# Out:
# /home/saul_gqb/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/saul_gqb/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Detección de outliers

# %% [markdown]
# Para la detección de outliers se utiliza la función ``plot_boxplot``, que se encarga de generar un conjunto de graficos de caja para cada una de las columnas de un dataframe dado y presentarlo a través de ``subplot()``, al igual que en el caso de ``plot_dis()`` con esto se facilita la visualización y se ahorra espacio en la notebook.

# %%
def plot_boxplot(df):
    plt.figure(figsize=(20,15))
    col = df.columns
    for i in range(len(df.columns)):
        plt.subplot(4, 3, i + 1)
        plt.boxplot(df[col[i]], vert=False)
        plt.title(col[i])
    
plot_boxplot(df_red)

# %% [markdown]
# Tal y como puede observarse, aparentemente existe una gran cantidad de datos atípicos en las columnas de datos, pues se encuentran por fuera de lo bigotes de los gráficos, esto podría atribuirse a la misma naturaleza de los datos, por lo que su remoción será puesta a consideración.

# %%
plot_boxplot(df_white)

# %% [markdown]
# Al igual que en el caso anterior aparentemente existe una gran cantidad de outliers en cietas columnas del dataframe **df_white**.

# %% [markdown]
# ### Eliminación de outliers

# %%
from outliers_treatment import outliers_detect
index_list_red = []
index_list_white = []
columns = df_red.columns.drop('quality')
for column in columns:
    index_list_red.extend(outliers_detect(df_red, column))
    index_list_white.extend(outliers_detect(df_white, column))

# %%
from outliers_treatment import remove_outliers
df_red_clean = remove_outliers(df_red, index_list_red)
df_white_clean = remove_outliers(df_white, index_list_white)
print(f'Red Wine: [len df_red: {len(df_red)}, len df_red_clean: {len(df_red_clean)}, outliers: {len(df_red)-len(df_red_clean)}]')
print(f'White Wine: [len df_white: {len(df_white)}, len df_white_clean: {len(df_white_clean)}], outliers: {len(df_white)-len(df_white_clean)}')
# Out:
# Red Wine: [len df_red: 1599, len df_red_clean: 1194, outliers: 405]
# White Wine: [len df_white: 4898, len df_white_clean: 4015], outliers: 883

# %%
df_red = df_red_clean
df_white = df_white_clean

# %% [markdown]
# ### Análisis de los targets (Wine Quality)

# %% [markdown]
# Tal y como puede observarse, los targets u objetivos que serán utilizados concisten en valores enteros (pues califican la calidad del vino). Para el caso del vino tinto (Red Wine Quality Count) la calidad varía entre 3 y 8, teniendo a 5 como la mayor frecuencia, mientras que para el vino blanco (White Wine Quality Count) la calidad varia entre 3 y 9, con la mayor frecuencia en 6.

# %%
plt.figure(figsize = (10,5))
plt.subplot(1, 2, 1)
sns.countplot(x = df_red['quality'])
plt.title('Red Wine Quality Count')
plt.ylabel('Frecuency')
plt.xlabel('Quality (Sensory preference)')
plt.subplot(1, 2, 2)
sns.countplot(x = df_white['quality'])
plt.title('White Wine Quality Count')
plt.ylabel('Frecuency')
plt.xlabel('Quality (Sensory preference)')
plt.show()

# %% [markdown]
# ### Análisis de los features

# %%
red_desc = df_red.describe().loc[['min', 'max', 'mean', 'std']].transpose().drop('quality')
white_desc = df_white.describe().loc[['min', 'max', 'mean', 'std']].transpose().drop('quality')
df_desc = pd.concat([red_desc, white_desc], axis = 1)

# %%
from IPython.display import HTML, display_html, display
display(HTML('<h4>Estadísticas por tipo de vino</h4>'))
display(HTML('<h5>Red whine data statistics / White whine data statistics</h5>'))
display_html(df_desc.round(2))
# Out:
# <h4>Estadísticas por tipo de vino</h4>
# <h5>Red whine data statistics / White whine data statistics</h5>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>fixed acidity</th>
#       <td>5.10</td>
#       <td>12.30</td>
#       <td>8.17</td>
#       <td>1.46</td>
#       <td>4.80</td>
#       <td>8.80</td>
#       <td>6.81</td>
#       <td>0.74</td>
#     </tr>
#     <tr>
#       <th>volatile acidity</th>
#       <td>0.12</td>
# ...

# %% [markdown]
# ### Aplicación de la función ``df.corr()`` y graficado

# %%
df_red.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.276094     0.662847
# volatile acidity          -0.276094          1.000000    -0.629348
# citric acid                0.662847         -0.629348     1.000000
# residual sugar             0.231532          0.027077     0.154331
# chlorides                  0.198035          0.111543     0.072543
# free sulfur dioxide       -0.150230         -0.016616    -0.071628
# total sulfur dioxide      -0.089681          0.101674    -0.001035
# density                    0.607073          0.043313     0.302619
# pH                        -0.684880          0.229799    -0.476570
# sulphates                  0.160881         -0.317344     0.257355
# alcohol                   -0.039232         -0.222267     0.141529
# quality                    0.110671         -0.352215     0.219897
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df_white.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.034750     0.242871
# volatile acidity          -0.034750          1.000000    -0.116044
# citric acid                0.242871         -0.116044     1.000000
# residual sugar             0.074312          0.069421     0.020582
# chlorides                  0.099023         -0.029796     0.032105
# free sulfur dioxide       -0.020947         -0.056347     0.087512
# total sulfur dioxide       0.086105          0.114423     0.096640
# density                    0.234060         -0.014644     0.065844
# pH                        -0.381297         -0.034649    -0.097118
# sulphates                 -0.002811         -0.020100     0.070200
# alcohol                   -0.094001          0.119420    -0.007110
# quality                   -0.054517         -0.115015     0.018355
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize = (20,8))
plt.subplot(1, 2, 1)
sns.heatmap(df_red.corr(), annot=True)
plt.title('Red Wine Correlation Heatmap')
plt.subplot(1, 2, 2)
sns.heatmap(df_white.corr(), annot=True)
plt.title('White Wine Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Aplicación con SKlearn para cada base de datos

# %% [markdown]
# ### Creacion de los DataFrame de Features y normalizandolos de 0 a 1 con la función  ``MinMaxScaler()`` de sklearn

# %%
X_red = df_red.drop(['quality'], axis=1)
X_white = df_white.drop(['quality'], axis=1)

# %%
scaler = MinMaxScaler()
x_red_columns = X_red.columns
x_white_columns = X_white.columns
for columna in x_red_columns:
    X_red[columna] = scaler.fit_transform(np.c_[X_red[columna]].reshape(-1, 1))

for columna in x_white_columns:
    X_white[columna] = scaler.fit_transform(np.c_[X_white[columna]].reshape(-1, 1))

# %%
X_red.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.319444          0.655367     0.000000        0.291667   0.448718
# 1       0.375000          0.858757     0.000000        0.583333   0.730769
# 2       0.375000          0.723164     0.054795        0.458333   0.653846
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.243902              0.241379  0.630058  0.770270   0.353846
# 1             0.585366              0.525862  0.514451  0.351351   0.538462
# 2             0.341463              0.413793  0.537572  0.432432   0.492308
#
#     alcohol
# 0  0.148936
# 1  0.234043
# 2  0.234043

# %%
X_white.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.550          0.469136     0.553191        0.939252   0.535714
# 1          0.375          0.543210     0.510638        0.046729   0.607143
# 2          0.825          0.493827     0.638298        0.294393   0.625000
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.551282              0.636752  0.935354  0.243243   0.425926
# 1             0.153846              0.474359  0.463973  0.648649   0.500000
# 2             0.358974              0.324786  0.538047  0.594595   0.407407
#
#     alcohol
# 0  0.068966
# 1  0.189655
# 2  0.293103

# %% [markdown]
# ### Creación de los DataFrames de Targets sin normalizar

# %%
Y_red = df_red['quality']
Y_white = df_white['quality']
Y_red.head(3)
# Out:
# 0    5
# 1    5
# 2    5
# Name: quality, dtype: int64

# %%
Y_white.head(3)
# Out:
# 0    6
# 1    6
# 2    6
# Name: quality, dtype: int64

# %% [markdown]
# ### Para exportar los datos a csv

# %% [markdown]
# Con las siguientes líneas de código se exportan los datos limpios y normalizados a csv en la carpeta datos del directorio local para ser utilizados en el ejercicio 5 inciso b).

# %% [markdown]
# red_wine_clean = pd.concat([X_red, Y_red], axis = 1)
# white_wine_clean = pd.concat([X_white, Y_white], axis = 1)

# %% [markdown]
# red_wine_clean.to_csv('datos/red_wine_clean.csv')
# white_wine_clean.to_csv('datos/white_wine_clean.csv')

# %% [markdown]
# ### Red wine quality prediction model

# %%
x_train_r, x_test_r, y_train_r, y_test_r = train_test_split(X_red, Y_red, test_size = 0.20, random_state = 42)

# %%
model_red = LinearRegression()
model_red.fit(x_train_r, y_train_r)
print(f'Bias: \n{model_red.intercept_}')
print(f'Weights: \n{model_red.coef_}')
# Out:
# Bias:
# 5.462845691267556
# Weights:
# [ 0.23509293 -0.79211915 -0.23512204 -0.00206402 -0.10076896  0.17283088
#  -0.30613975 -0.34866092 -0.3838208   1.08755567  1.29994162]

# %%
predictions_red = model_red.predict(x_test_r)

# %%
MAE_red = round(metrics.mean_absolute_error(y_test_r, predictions_red), 3)
MAPE_red = round(metrics.mean_absolute_percentage_error(y_test_r, predictions_red), 3)
print(f'Red Wine MAE: {MAE_red}')
print(f'Red Wine MAPE: {MAPE_red}')
# Out:
# Red Wine MAE: 0.443
# Red Wine MAPE: 0.077

# %%
plt.scatter(predictions_red, y_test_r)
plt.title('Red wine quality scatter plot', fontsize=14)
plt.xlabel('Red wine quality prediction', fontsize=12)
plt.ylabel('Red wine quality', fontsize=12)
plt.show()

# %% [markdown]
# ### White wine quiality prediction model

# %%
x_train_w, x_test_w, y_train_w, y_test_w = train_test_split(X_white, Y_white, test_size = 0.20, random_state = 42)

# %%
model_white = LinearRegression()
model_white.fit(x_train_w, y_train_w)
print(f'Bias: \n{model_white.intercept_}')
print(f'Weights: \n{model_white.coef_}')
# Out:
# Bias:
# 5.804411316219905
# Weights:
# [ 0.61495032 -0.79709482  0.03849272  2.03172317 -0.24564387  0.41585912
#   0.03978991 -2.83744809  0.6926513   0.41946774  0.78958888]

# %%
predictions_white = model_white.predict(x_test_w)

# %%
MAE_white = round(metrics.mean_absolute_error(y_test_w, predictions_white), 3)
MAPE_white = round(metrics.mean_absolute_percentage_error(y_test_w, predictions_white), 3)
print(f'White Wine MAE: {MAE_white}')
print(f'White Wine MAPE: {MAPE_white}')
# Out:
# White Wine MAE: 0.579
# White Wine MAPE: 0.1

# %%
plt.scatter(predictions_white, y_test_w)
plt.title('White wine quality scatter plot', fontsize=14)
plt.xlabel('White wine quality prediction', fontsize=12)
plt.ylabel('White wine quality', fontsize=12)
plt.show()

# %% [markdown]
# ### Resumen y comparación entre ambos modelos

# %%
resultados = pd.DataFrame({'Indicador': ['MAE', 'MAPE'], 'Red Wine': [MAE_red, MAPE_red], 'White Wine': [MAE_white, MAPE_white]})
resultados = resultados.set_index('Indicador')
display(HTML('<h4>Resultados obtenidos para los modelos implementados</h4>'))
display_html(resultados)
# Out:
# <h4>Resultados obtenidos para los modelos implementados</h4>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Red Wine</th>
#       <th>White Wine</th>
#     </tr>
#     <tr>
#       <th>Indicador</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MAE</th>
#       <td>0.443</td>
#       <td>0.579</td>
#     </tr>
#     <tr>
#       <th>MAPE</th>
#       <td>0.077</td>
#       <td>0.100</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.scatter(predictions_red, y_test_r)
plt.title('Red wine quality scatter plot', fontsize=14)
plt.xlabel('Red wine quality prediction', fontsize=12)
plt.ylabel('Red wine quality', fontsize=12)
plt.subplot(1, 2, 2)
plt.scatter(predictions_white, y_test_w)
plt.title('White wine quality scatter plot', fontsize=14)
plt.xlabel('White wine quality prediction', fontsize=12)
plt.ylabel('White wine quality', fontsize=12)
plt.show()
